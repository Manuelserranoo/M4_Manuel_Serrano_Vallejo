# %% [markdown]
# Ejercicio 1

# %% [markdown]
# A) Importamos pandas y le asignamos el valor pd.

# %%
import pandas as

# %% [markdown]
# B) Cargamos el archivo CSV  mediante pd.read_csv(...) y lo guardamos en la variable elenco para llamarlo con más facilidad,finalmente leemos sus 5 primeros registros con eleneco.head(5).

# %%
elenco = pd.read_csv("/workspaces/codespaces-jupyter/data/datos/imdb_elenco.csv")

# %%
elenco.head(5)
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# C) Realizamos lo mismo que en el anterior apartado pero llamamos a la variable titulos.

# %%
titulos = pd.read_csv("/workspaces/codespaces-jupyter/data/datos/imdb_titulos (1).csv")

# %%
titulos.head(5)
# Out:
#                                    title  year
# 0                                 Mahler  1974
# 1           Ogon, voda i... mednye truby  1968
# 2  Ana Nojoom bent alasherah wamotalagah  2014
# 3                      Malu de Bicicleta  2010
# 4             Nazareno Apostol: Boy Ahas  1989

# %% [markdown]
# D) Mediante la función titulos.axes contamos el numero de filas o columnas pero al poner [0] nos estamos refieriendo a las filas.

# %%
registrostitulos = len(titulos.axes[0])

print("Nº de registros de titulos:",str(registrostitulos))
# Out:
# Nº de registros de titulos: 230407

# %% [markdown]
# E) Mismo método que el anterior.

# %%
registroselenco = len(elenco.axes[0])
print("Nº de registros de elenco:",str(registroselenco))
# Out:
# Nº de registros de elenco: 3564650

# %% [markdown]
# F) Usando titulos.nsmallest obtiene el valor mínimo y luego le especificamos que queremos los 5 registros más pequeños de la columna "year".

# %%
titulos.nsmallest(5, ["year"])
# Out:
#                                                  title  year
# 13229                                       Miss Jerry  1894
# 103233                              The Startled Lover  1898
# 133020  Reproduction of the Corbett and Jeffries Fight  1899
# 51528                             Family Troubles (II)  1900
# 111320                        Trouble in Hogan's Alley  1900

# %% [markdown]
# G) Dentro de titulos hacemeos que nos muestren solo aquellos que en la columna "title" sean = a "Dracula".

# %%
titulos[titulos.title == "Dracula"]
# Out:
#           title  year
# 30479   Dracula  1992
# 35229   Dracula  1958
# 62596   Dracula  1999
# 94156   Dracula  1931
# 156968  Dracula  2019
# 184003  Dracula  1979

# %% [markdown]
# Calculamos el número mediante len que nos mide el número de filas que tiene la nueva lista.

# %%
len(titulos[titulos.title == "Dracula"])
# Out:
# 6

# %% [markdown]
# H) Para este apartado utilizamos .value_counts() para que haga grupos con los valores que se repiten en la culomna titulos y nos muestre los que más se repiten.

# %%
rep = titulos["title"].value_counts()
rep
# Out:
# Hamlet                   19
# Carmen                   16
# Macbeth                  15
# Maya                     11
# The Outsider             11
#                          ..
# My First Wedding          1
# Those Without Shadows     1
# Que Poca Madre            1
# Bondam Pelli              1
# Mio caro assassino        1
# Name: title, Length: 210691, dtype: int64

# %% [markdown]
# Como solo necesitamos los 10 más repetidos pedimos que imprima los 10 primeros con .head(10).

# %%
rep.head(10)
# Out:
# Hamlet                  19
# Carmen                  16
# Macbeth                 15
# Maya                    11
# The Outsider            11
# Hero                    11
# Othello                 11
# The Three Musketeers    11
# Anna                    10
# Vengeance               10
# Name: title, dtype: int64

# %% [markdown]
# I) Como nos piden la pélicula llamada "Romeo and Juliet" más antigua primero aislamos todas las llamadas así buscando en titulos.title las que tienen ese nombre.

# %%
ryj = titulos[titulos.title == "Romeo and Juliet"]
ryj
# Out:
#                    title  year
# 16975   Romeo and Juliet  2014
# 82622   Romeo and Juliet  1936
# 87037   Romeo and Juliet  1954
# 124702  Romeo and Juliet  1916
# 144796  Romeo and Juliet  2013
# 147308  Romeo and Juliet  1947
# 185337  Romeo and Juliet  1968
# 196039  Romeo and Juliet  1966

# %% [markdown]
# Como necesitamos la más pequeña utilizamos al igual que anteriormente nsmallest en la columna de "year"

# %%
ryj.nsmallest(1, ["year"])
# Out:
#                    title  year
# 124702  Romeo and Juliet  1916

# %% [markdown]
# J) Como necesitamos las peliculas que contengan la palabra "Exorcist" no nos vale con el método del ejercicio anterior por lo que buscamos dentro de title mediante .str.contains("Exorcist) los títulos que contengan esta palabra.

# %%
exo = titulos[titulos["title"].str.contains("Exorcist")]
exo
# Out:
#                                          title  year
# 17375                         The Exorcist III  1990
# 49658                  O Exorcista de Mulheres  1974
# 51101                            Bad Exorcists  2015
# 57932                      Exorcist Chronicles  2013
# 60700                      Accidental Exorcist  2016
# 69974                           Shark Exorcist  2015
# 86354                      Exorcist Chronicles  2007
# 88003                             The Exorcist  1973
# 94189        Dominion: Prequel to the Exorcist  2005
# 117797                 Exorcist: The Beginning  2004
# 130686                      The Disco Exorcist  2011
# 132451                        Teenage Exorcist  1991
# 140519                Exorcist II: The Heretic  1977
# 151850                              Exorcistas  2015
# 161093                       American Exorcist  2016
# 195615                    Diary of an Exorcist  2016
# 209250  Costa Chica: Confession of an Exorcist  2006
# ...

# %% [markdown]
# Los ordenamos de menos a mayor con .sort_values

# %%
exo.sort_values(by = "year")
# Out:
#                                          title  year
# 88003                             The Exorcist  1973
# 49658                  O Exorcista de Mulheres  1974
# 140519                Exorcist II: The Heretic  1977
# 220073                        Kung Fu Exorcist  1978
# 17375                         The Exorcist III  1990
# 132451                        Teenage Exorcist  1991
# 117797                 Exorcist: The Beginning  2004
# 94189        Dominion: Prequel to the Exorcist  2005
# 209250  Costa Chica: Confession of an Exorcist  2006
# 86354                      Exorcist Chronicles  2007
# 130686                      The Disco Exorcist  2011
# 57932                      Exorcist Chronicles  2013
# 69974                           Shark Exorcist  2015
# 51101                            Bad Exorcists  2015
# 151850                              Exorcistas  2015
# 60700                      Accidental Exorcist  2016
# 161093                       American Exorcist  2016
# ...

# %% [markdown]
# K) Aislamos los registros del año 1950.

# %%
pl = titulos[titulos["year"] == 1950]
pl
# Out:
#                        title  year
# 68         Emei fei jian xia  1950
# 176                  Hua jie  1950
# 223                 Spy Hunt  1950
# 376                  Sarumba  1950
# 522             Onu affettim  1950
# ...                      ...   ...
# 230060  Deadly Is the Female  1950
# 230125    Magkumpareng Putik  1950
# 230136   Kanske en gentleman  1950
# 230227    Dick Barton at Bay  1950
# 230278        Alakh Niranjan  1950
#
# [1081 rows x 2 columns]

# %% [markdown]
# mediante len() calculamos la longitud de la nueva lista.

# %%
len(pl)
# Out:
# 1081

# %% [markdown]
# L) Para tener un rango de años primero nos centramos en aquellos > o = a 1950 y luego en la nueva lista nos centramos en los menores o iguales a 1959.

# %%
d = titulos[titulos["year"] >= 1950 ]

# %%
f = d[titulos["year"] <= 1959]
f
# Out:
# /tmp/ipykernel_13602/3576905807.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   f = d[titulos["year"] <= 1959]
#                                   title  year
# 17                      Take Me to Town  1953
# 20                           Dolgiy put  1957
# 36              La sonrisa de la Virgen  1958
# 54                       Grabenplatz 17  1958
# 68                    Emei fei jian xia  1950
# ...                                 ...   ...
# 230370            The Son of Dr. Jekyll  1951
# 230372                     Quiero vivir  1953
# 230376  The Phantom from 10,000 Leagues  1955
# 230387                  No Holds Barred  1952
# 230399                           Rajput  1951
#
# [12606 rows x 2 columns]

# %% [markdown]
# M) Buscamos en el apartado "title" de elenco "The Godfather"

# %%
e = elenco[elenco.title == "The Godfather"]
e
# Out:
#                  title  year                  name     type  \
# 51214    The Godfather  1972       Chris Anastasio    actor
# 102809   The Godfather  1972      Norm Bacchiocchi    actor
# 220852   The Godfather  1972             Rudy Bond    actor
# 248000   The Godfather  1972         Marlon Brando    actor
# 248738   The Godfather  1972            Max Brandt    actor
# ...                ...   ...                   ...      ...
# 3137607  The Godfather  1972          Carol Morley  actress
# 3360381  The Godfather  1972       Ardell Sheridan  actress
# 3363276  The Godfather  1972           Talia Shire  actress
# 3390198  The Godfather  1972    Filomena Spagnuolo  actress
# 3399922  The Godfather  1972  Simonetta Stefanelli  actress
#
#                                character     n
# 51214                          Policeman   NaN
# 102809             Luca Brasi's Assassin   NaN
# 220852                             Cuneo  15.0
# 248000                 Don Vito Corleone   1.0
# ...

# %% [markdown]
# Mediante e.iloc [:,4] nos quedamos solo con la columna que buscamos.

# %%
c = e.iloc[:, 4]
c
# Out:
# 51214                            Policeman
# 102809               Luca Brasi's Assassin
# 220852                               Cuneo
# 248000                   Don Vito Corleone
# 248738     Extra in Furniture-Moving Scene
#                         ...
# 3137607                        Night Nurse
# 3360381                      Mrs. Clemenza
# 3363276                             Connie
# 3390198             Extra in Wedding Scene
# 3399922      Apollonia - Sicilian Sequence
# Name: character, Length: 76, dtype: object

# %% [markdown]
# Para ver que valores se repiten utilizamos en la nueva lista c la función value_counts().

# %%
papeles = c.value_counts()
papeles
# Out:
# Wedding Guest                    2
# Policeman                        1
# Drunk                            1
# Willi Cicci                      1
# Street Extra                     1
#                                 ..
# Sonny's Bodyguard                1
# Anthony Vito Corleone            1
# Bruno Tattaglia                  1
# Usher in Bridal Party            1
# Apollonia - Sicilian Sequence    1
# Name: character, Length: 75, dtype: int64

# %% [markdown]
# N) Buscamos las peliculas que se llamen "Dracula".

# %%
drac = elenco[elenco.title == "Dracula"]
drac
# Out:
#            title  year                     name     type  \
# 128076   Dracula  1992               Ele Bardha    actor
# 148496   Dracula  1958         Geoffrey Bayldon    actor
# 159194   Dracula  1931            Nicholas Bela    actor
# 159765   Dracula  1979              Joe Belcher    actor
# 171732   Dracula  1958            George Benson    actor
# ...          ...   ...                      ...      ...
# 3481947  Dracula  1931          Josephine Velez  actress
# 3493302  Dracula  1992  Tatiana von Furstenberg  actress
# 3531424  Dracula  1992          Maud Winchester  actress
# 3534975  Dracula  1931             Florence Wix  actress
# 3564263  Dracula  1992                Eniko ?ss  actress
#
#                            character     n
# 128076                  Grave Digger   NaN
# 148496                        Porter  16.0
# 159194               Coach Passenger   NaN
# 159765                   Tom Hindley  12.0
# 171732                      Official  14.0
# ...

# %% [markdown]
# Para ordenarlas por el valor n ordenamos que la lista nueva se ordene de menos a mayor con .nsmallest.

# %%
drac.nsmallest(113,["n"])
# Out:
#            title  year             name     type                    character  \
# 1310001  Dracula  1931      Bela Lugosi    actor                Count Dracula
# 1621348  Dracula  1992      Gary Oldman    actor                      Dracula
# 1217694  Dracula  1979   Frank Langella    actor                Count Dracula
# 485197   Dracula  1958    Peter Cushing    actor           Doctor Van Helsing
# 2585148  Dracula  1931   Helen Chandler  actress                         Mina
# ...          ...   ...              ...      ...                          ...
# 3338281  Dracula  1992   Heidi Schooler  actress              Young Courtesan
# 3438495  Dracula  1931    Cornelia Thaw  actress               Dracula's Wife
# 3455419  Dracula  1931     Dorothy Tree  actress               Dracula's Wife
# 3481947  Dracula  1931  Josephine Velez  actress        Grace - English Nurse
# 3534975  Dracula  1931     Florence Wix  actress  Concertgoer Outside Theatre
#
#            n
# 1310001  1.0
# ...

# %% [markdown]
# O) Buscamos el valor "Bruce Wayne" en la columna character.

# %%
b = elenco[elenco.character == "Bruce Wayne"]
b
# Out:
#                                                      title  year  \
# 1001                                 Batman Fights Dracula  1967
# 15783                   Batman v Superman: Dawn of Justice  2016
# 15809                                       Justice League  2017
# 15825                                        Suicide Squad  2016
# 77677                                The Lego Batman Movie  2017
# 77679                                       The Lego Movie  2014
# 117412                                       Batman Begins  2005
# 117443                                     The Dark Knight  2008
# 117444                               The Dark Knight Rises  2012
# 222593                                           She Kills  2016
# 313015                             B@ (Batman Parody Film)  2016
# 414272                                      Batman & Robin  1997
# 436781                        Batman: Mask of the Phantasm  1993
# ...

# %% [markdown]
# Medimos la longitud de la lista con len().

# %%
len(b)
# Out:
# 38

# %% [markdown]
# P) Seguimos la misma técnica que en anterior apartado.

# %%
r = elenco[elenco.name == "Robert De Niro"]
r
# Out:
#                                                   title  year            name  \
# 525856                                       15 Minutes  2001  Robert De Niro
# 525857                                     A Bronx Tale  1993  Robert De Niro
# 525858                                  American Hustle  2013  Robert De Niro
# 525859                                     Analyze That  2002  Robert De Niro
# 525860                                     Analyze This  1999  Robert De Niro
# ...                                                 ...   ...             ...
# 525954                                 True Confessions  1981  Robert De Niro
# 525955  Untitled De Niro - Ramirez - Jakubowicz Project  2017  Robert De Niro
# 525956                                      Wag the Dog  1997  Robert De Niro
# 525957                                  We're No Angels  1989  Robert De Niro
# 525958                               What Just Happened  2008  Robert De Niro
#
# ...

# %%
len(r)
# Out:
# 103

# %% [markdown]
# Q) En este caso necesitamos encadenar varias funciones para conseguir la lista con requisitos que nos piden.

# %%
s = elenco[elenco.name == "Charlton Heston"]

# %%
z = s[elenco.n == 1]
# Out:
# /tmp/ipykernel_13602/4216203518.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   z = s[elenco.n == 1]

# %%
k = z[elenco["year"] >= 1950 ]
# Out:
# /tmp/ipykernel_13602/3243604121.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   k = z[elenco["year"] >= 1950 ]

# %%
k[elenco["year"] <= 1959 ]
# Out:
# /tmp/ipykernel_13602/1102602303.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   k[elenco["year"] <= 1959 ]
#                                   title  year             name   type  \
# 944045                        Arrowhead  1953  Charlton Heston  actor
# 944046               Bad for Each Other  1953  Charlton Heston  actor
# 944047                          Ben-Hur  1959  Charlton Heston  actor
# 944051                        Dark City  1950  Charlton Heston  actor
# 944079                     Pony Express  1953  Charlton Heston  actor
# 944081              Secret of the Incas  1954  Charlton Heston  actor
# 944106  The Private War of Major Benson  1955  Charlton Heston  actor
# 944107                       The Savage  1952  Charlton Heston  actor
# 944108                       The Savage  1952  Charlton Heston  actor
# 944109             The Ten Commandments  1956  Charlton Heston  actor
# ...

# %% [markdown]
# R) En este apartado nos quedamos con la lista solamente de los años 50´s y luego medimos la longitud en el caso de que sean actores y en el caso de que sean actrices.

# %%
w = elenco[elenco["year"] <= 1949]

# %%
y = w[elenco["year"] >= 1940]
# Out:
# /tmp/ipykernel_13602/2182227269.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   y = w[elenco["year"] >= 1940]

# %%
len(w[elenco.type == "actor"])
# Out:
# /tmp/ipykernel_13602/904046814.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(w[elenco.type == "actor"])
# 384187

# %%
len(w[elenco.type == "actress"])
# Out:
# /tmp/ipykernel_13602/2264646808.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(w[elenco.type == "actress"])
# 138590
